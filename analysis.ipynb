# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from ydata_profiling import ProfileReport

# %%
malaria = pd.read_csv(r"datasets\Malaria_Dataset.csv")
malaria.head()
# Out:
#   IP_Number  Age  ... Target Risk_Score
# 0  14xxxx31   52  ...      0          3
# 1  28xxxx34   75  ...      1         11
# 2  96xxxx43   30  ...      1         13
# 3  49xxxx87   89  ...      0          5
# 4  48xxxx10   62  ...      1          8
#
# [5 rows x 21 columns]

# %%
print(f"This dataset has {malaria.shape[0]} rows and {malaria.shape[1]} columns")
# Out:
# This dataset has 1622 rows and 21 columns

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1622 entries, 0 to 1621
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IP_Number             1622 non-null   object
#  1   Age                   1622 non-null   int64
#  2   Sex                   1622 non-null   object
#  3   Residence_Area        1622 non-null   object
#  4   DOA                   1622 non-null   object
#  5   Discharge_Date        1622 non-null   object
#  6   Fever                 1622 non-null   int64
#  7   Headache              1622 non-null   int64
#  8   Abdominal_Pain        1622 non-null   int64
#  9   General_Body_Malaise  1622 non-null   int64
#  10  Dizziness             1622 non-null   int64
#  11  Vomiting              1622 non-null   int64
#  12  Confusion             1622 non-null   int64
#  13  Backache              1622 non-null   int64
#  14  Chest_Pain            1622 non-null   int64
# ...

# %%
#change the date columns to datetime format, and handle any errors by coercing them to NaT (Not a Time) if they cannot be converted.
malaria['DOA'] = pd.to_datetime(malaria['DOA'], dayfirst=True, errors='coerce')
malaria['Discharge_Date'] = pd.to_datetime(malaria['Discharge_Date'], dayfirst=True, errors='coerce')

# %% [markdown]
# ### Report

# %%
# EDA using ydata_profiling
profile = ProfileReport(malaria, title= 'my report', explorative=True)
profile.to_file(r"reports and documentations/malaria_training_data.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
